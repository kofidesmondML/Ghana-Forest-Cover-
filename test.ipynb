# %%
import pandas as pd

# %%
forest_path = './clean_data/forest.csv'
forest_df = pd.read_csv(forest_path)

license_check = forest_df[['subnational2', 'Number of Licenses']]
nan_licenses = license_check[license_check['Number of Licenses'].isna()]['subnational2']
nan_licenses_sorted = sorted(nan_licenses.to_list())

print(nan_licenses_sorted)
forest_df
# Out:
# ['Abura-Asebu-Kwamankese', 'Adaklu Anyigbe', 'Adansi North', 'Afigya Sekyere', 'Afram Plains', 'Agona', 'Ahafo Ano North', 'Ahafo Ano South', 'Ahanta West', 'Ajumako-Enyan-Esiam', 'Akatsi', 'Akwapim North', 'Akwapim South', 'Amansie East', 'Aowin-Suaman', 'Asante Akim North', 'Asante Akim South', 'Asikuma Odoben Brakwa', 'Assin South', 'Asunafo North', 'Asuogyaman', 'Asutifi', 'Atebubu-Amantin', 'Atwima', 'Awutu Efutu Senya', 'Bawku Municipal', 'Bawku West', 'Berekum', 'Bia', 'Bibiani Anhwiaso Bekwai', 'Birim South', 'Bole', 'Bongo', 'Bosomtwe-Kwanwoma', 'Builsa', 'Bunkpurugu Yunyoo', 'Central Gonja', 'Dangbe East', 'Dangbe West', 'Dormaa', 'East Akim', 'East Gonja', 'East Mamprusi', 'Ejisu-Juabeng', 'Ejura Sekyedumase', 'Fanteakwa', 'Ga East', 'Ga West', 'Garu Tempane', 'Gomoa', 'Gushiegu', 'Ho', 'Hohoe', 'Jaman North', 'Jaman South', 'Jasikan', 'Jirapa Lambussie', 'Juabeso', 'Kadjebi', 'Karaga', 'Kassena Nankana', 'Keta', 'Ketu', 'Kintampo North', 'Kintampo South', 'Komenda-Edina-Eguafo-Abirem', 'Kpandu', 'Krachi', 'Krachi East', 'Kwabibirem', 'Kwabre', 'Kwahu South', 'Kwahu West', 'Lawra', 'Lower Denkyira', 'Manya Krobo', 'Mfantsiman', 'Mpohor Wassa East', 'Nadowli', 'Nanumba North', 'Nanumba South', 'New Juaben', 'Nkoranza', 'Nkwanta', 'North Tongu', 'Obuasi Municipal', 'Offinso', 'Pru', 'Saboba Chereponi', 'Savelugu Nanton', 'Sawa-Tuna-Kalba', 'Sekyere East', 'Sekyere West', 'Sene', 'Shama Ahanta East', 'Sissala East', 'Sissala West', 'South Dayi', 'South Tongu', 'Suhum Kraboa Coaltar', 'Sunyani', 'Tain', 'Talensi Nabdam', 'Tamale', 'Tano North', 'Tano South', 'Tema', 'Tolon-Kumbungu', 'Upper Denkyira', 'Wa East', 'Wa West', 'Wasa Amenfi East', 'Wasa Amenfi West', 'West Akim', 'West Gonja', 'West Mamprusi', 'Yendi', 'Yilo Krobo', 'Zabzugu Tatale']
#      Unnamed: 0.1  Unnamed: 0 country subnational1       subnational2  \
# 0               0           0   Ghana      Ashanti       Adansi North
# 1               1           1   Ghana      Ashanti       Adansi South
# 2               2           2   Ghana      Ashanti     Afigya Sekyere
# 3               3           3   Ghana      Ashanti    Ahafo Ano North
# 4               4           4   Ghana      Ashanti    Ahafo Ano South
# ..            ...         ...     ...          ...                ...
# 132           132         132   Ghana      Western       Sefwi Wiawso
# 133           133         133   Ghana      Western  Shama Ahanta East
# 134           134         134   Ghana      Western   Wasa Amenfi East
# 135           135         135   Ghana      Western   Wasa Amenfi West
# 136           136         136   Ghana      Western         Wassa West
#
#      threshold  area_ha  extent_2000_ha  extent_2010_ha  gain_2000-2020_ha  \
# 0           75    61269            4520            2921               2041
# 1           75   140792            8051            8276               3296
# 2           75    66797             454             193               1516
# 3           75    72965             141              59               1538
# 4           75   120724            3548            5870               3563
# ..         ...      ...             ...             ...                ...
# 132         75   246906            9954            7387               3578
# 133         75    39709             337              77               2544
# 134         75   151748            6595            3425               1936
# 135         75   317025            6558            6360               4898
# 136         75   258492           10975            3879               6049
#
#      ...  tc_loss_ha_2015  tc_loss_ha_2016  tc_loss_ha_2017  tc_loss_ha_2018  \
# 0    ...                5               17                6                8
# 1    ...                1               24                6               54
# 2    ...                0                0                0                0
# 3    ...                0                0                0                0
# 4    ...               10              197               96               91
# ..   ...              ...              ...              ...              ...
# 132  ...               16               23               33               52
# 133  ...                0                0                0                0
# 134  ...                4                6                4                6
# 135  ...                1                5                7               12
# 136  ...               29               19               20               38
#
#      tc_loss_ha_2019  tc_loss_ha_2020  tc_loss_ha_2021  tc_loss_ha_2022  \
# 0                 11               31               16               21
# 1                 34               94               69               94
# 2                  0                0                0                0
# 3                  0                0                1                0
# 4                  7              139               35               52
# ..               ...              ...              ...              ...
# 132               67              127              118              192
# 133                0                0                0                0
# 134                4               20                8               12
# 135               10               10               11               12
# 136               17               23                9               20
#
#      tc_loss_ha_2023  Number of Licenses
# 0                 31                 NaN
# 1                 86                 5.0
# 2                  0                 NaN
# 3                  1                 NaN
# 4                 24                 NaN
# ..               ...                 ...
# 132               53                25.0
# 133                0                 NaN
# 134               13                 NaN
# 135                5                 NaN
# 136               25                 1.0
#
# [137 rows x 34 columns]

# %%
license=pd.read_csv('./clean_data/district_license_count.csv')
license
# Out:
#                             District  Number of Licenses
# 0                Abosso Sub Location                   1
# 1                     Accra District                   1
# 2                    Adanse District                   1
# 3           Adansi Akrofuom District                   2
# 4              Adansi South District                   5
# 5               Ahafo Goaso District                  67
# 6                       Ahafo Region                   3
# 7           Amansie Central District                  11
# 8              Amansie West District                  21
# 9              Aowin/Suaman District                   3
# 10                    Ashanti Region                   5
# 11              Assin North District                   2
# 12            Asunafo South District                   4
# 13            Asutifi South District                   1
# 14                    Atiwa District                  11
# 15            Atwima Mponua District                   1
# 16              Birim North District                   8
# 17               Bolgatanga District                  24
# 18                Brong Ahafo Region                   2
# 19               Cape Coast District                 148
# 20                    Central Region                   8
# 21                  Damango District                   5
# 22                   Jomoro District                   1
# 23                Koforidua District                 181
# 24                   Kumasi District                 266
# 25              Kwaebibirem District                   1
# 26  Kwahu West Municipality District                   1
# 27                 Nalerigu District                   2
# 28               Nzema East District                   1
# 29      Prestea Huni Valley District                  10
# 30                   Savannah Region                   1
# 31             Sefwi Wiawso District                  25
# 32         Sekondi Takoradi District                  59
# 33                 Techiman District                   1
# 34      Upper Denkyira East District                   1
# 35      Upper Denkyira West District                   5
# 36                 Upper West Region                   1
# 37                       Wa District                   1
# 38        Wassa Amenfi East District                   1
# 39               Wassa West District                   1
# 40              Western North Region                  15
# 41                    Western Region                   8

# %%
missing_data={'Wassa Amenfi East':1,
            'Wassa West':1,
            'Wa East':1,
            'Wa West':0,
            'Wa East':1,
            'Upper Denkyira':6,
            'Kwahu West':1,
            'Kwabibrem':1,
            'Asutifi':1,
            'Aowin-Suaman':3}

# %%
license_df = pd.read_csv('./clean_data/license.csv')
license_df
small_scale_active_licenses = license_df[
    (license_df['Type'].str.contains('Small Scale', case=False, na=False)) & 
    (license_df['Status'] == 'Active License')
]
print(sorted(license_df['Regions'].to_list()))


for district, licenses in missing_data.items():
    forest_df.loc[forest_df['subnational2'] == district, 'Number of Licenses'] = licenses
forest_df.to_csv('./clean_data/updated_forest.csv', index=False)
print(forest_df[['subnational2', 'Number of Licenses']].head(100))
# Out:
# ['Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAhafo Goaso District', 'Ahafo Region\nAshanti Region\nAhafo Goaso District\nKumasi District', 'Ahafo Region\nAshanti Region\nAhafo Goaso District\nKumasi District', 'Ahafo Region\nAshanti Region\nAhafo Goaso District\nKumasi District', 'Ahafo Region\nAshanti Region\nKumasi District\nAhafo Goaso District', 'Ahafo Region\nAshanti Region\nKumasi District\nAhafo Goaso District', 'Ahafo Region\nAshanti Region\nKumasi District\nAhafo Goaso District', 'Ahafo Region\nBrong Ahafo Region\nAsunafo South District\nAhafo Goaso District', 'Ahafo Region\nBrong Ahafo Region\nAsunafo South District\nAhafo Goaso District', 'Ahafo Region\nBrong Ahafo Region\nAsunafo South District\nAhafo Goaso District', 'Ahafo Region\nBrong Ahafo Region\nAsunafo South District\nAhafo Goaso District', 'Ahafo Region\nBrong Ahafo Region\nAsunafo South District\nAhafo Goaso District', 'Ahafo Region\nBrong Ahafo Region\nAsunafo South District\nAhafo Goaso District', 'Ashanti Region\nAdansi Akrofuom District', 'Ashanti Region\nAdansi Akrofuom District\nKumasi District', 'Ashanti Region\nAdansi Akrofuom District\nKumasi District', 'Ashanti Region\nAdansi South District', 'Ashanti Region\nAhafo Region\nKumasi District\nAhafo Goaso District', 'Ashanti Region\nAhafo Region\nKumasi District\nAhafo Goaso District', 'Ashanti Region\nAhafo Region\nKumasi District\nAhafo Goaso District', 'Ashanti Region\nAmansie Central District', 'Ashanti Region\nAmansie Central District\nKumasi District', 'Ashanti Region\nAmansie Central District\nKumasi District', 'Ashanti Region\nAmansie West District', 'Ashanti Region\nAmansie West District', 'Ashanti Region\nAmansie West District', 'Ashanti Region\nAmansie West District', 'Ashanti Region\nAmansie West District', 'Ashanti R ...
#        subnational2  Number of Licenses
# 0      Adansi North                 NaN
# 1      Adansi South                 5.0
# 2    Afigya Sekyere                 NaN
# 3   Ahafo Ano North                 NaN
# 4   Ahafo Ano South                 NaN
# ..              ...                 ...
# 95       Bolgatanga                24.0
# 96            Bongo                 NaN
# 97           Builsa                 NaN
# 98     Garu Tempane                 NaN
# 99  Kassena Nankana                 NaN
#
# [100 rows x 2 columns]

# %%
import numpy as np

# %%
last_sequence_1 = np.array([
    [[0.00229885], 
     [0.0], 
     [0.00229885], 
     [0.0], 
     [0.0137931], 
     [0.0], 
     [0.00229885], 
     [0.0091954], 
     [0.04137931]]
])

# %%
last_sequence_1[:, 1:, :]
# Out:
# array([[[0.        ],
#         [0.00229885],
#         [0.        ],
#         [0.0137931 ],
#         [0.        ],
#         [0.00229885],
#         [0.0091954 ],
#         [0.04137931]]])

# %%
last_sequence_1.shape
# Out:
# (1, 9, 1)

# %%
import random
random_number1 = random.randint(1000000, 9999999)
random_number2 = random.randint(1000000, 9999999)

print(random_number1, random_number2)
# Out:
# 9409766 4494635

# %%
random_number1 = random.randint(10**14, 10**15 - 1)
random_number2 = random.randint(10**14, 10**15 - 1)

print(random_number1, random_number2)
# Out:
# 414718413412005 879967817304893

# %%
import pandas as pd 
file_path = './clean_data/forest.csv'
data = pd.read_csv(file_path)
data
# Out:
#     country subnational1       subnational2  threshold  area_ha  \
# 0     Ghana      Ashanti       Adansi North         75    61269
# 1     Ghana      Ashanti       Adansi South         75   140792
# 2     Ghana      Ashanti     Afigya Sekyere         75    66797
# 3     Ghana      Ashanti    Ahafo Ano North         75    72965
# 4     Ghana      Ashanti    Ahafo Ano South         75   120724
# ..      ...          ...                ...        ...      ...
# 132   Ghana      Western       Sefwi Wiawso         75   246906
# 133   Ghana      Western  Shama Ahanta East         75    39709
# 134   Ghana      Western   Wasa Amenfi East         75   151748
# 135   Ghana      Western   Wasa Amenfi West         75   317025
# 136   Ghana      Western         Wassa West         75   258492
#
#      extent_2000_ha  extent_2010_ha  gain_2000-2020_ha  tc_loss_ha_2001  \
# 0              4520            2921               2041               23
# 1              8051            8276               3296              122
# 2               454             193               1516              100
# 3               141              59               1538               39
# 4              3548            5870               3563              148
# ..              ...             ...                ...              ...
# 132            9954            7387               3578              186
# 133             337              77               2544               49
# 134            6595            3425               1936               84
# 135            6558            6360               4898              424
# 136           10975            3879               6049              479
#
#      tc_loss_ha_2002  ...  tc_loss_ha_2014  tc_loss_ha_2015  tc_loss_ha_2016  \
# 0                 80  ...               40                5               17
# 1                129  ...               12                1               24
# 2                122  ...                0                0                0
# 3                  8  ...                0                0                0
# 4                313  ...               44               10              197
# ..               ...  ...              ...              ...              ...
# 132              138  ...               24               16               23
# 133               95  ...                0                0                0
# 134              476  ...                6                4                6
# 135              706  ...                9                1                5
# 136             1079  ...               32               29               19
#
#      tc_loss_ha_2017  tc_loss_ha_2018  tc_loss_ha_2019  tc_loss_ha_2020  \
# 0                  6                8               11               31
# 1                  6               54               34               94
# 2                  0                0                0                0
# 3                  0                0                0                0
# 4                 96               91                7              139
# ..               ...              ...              ...              ...
# 132               33               52               67              127
# 133                0                0                0                0
# 134                4                6                4               20
# 135                7               12               10               10
# 136               20               38               17               23
#
#      tc_loss_ha_2021  tc_loss_ha_2022  tc_loss_ha_2023
# 0                 16               21               31
# 1                 69               94               86
# 2                  0                0                0
# 3                  1                0                1
# 4                 35               52               24
# ..               ...              ...              ...
# 132              118              192               53
# 133                0                0                0
# 134                8               12               13
# 135               11               12                5
# 136                9               20               25
#
# [137 rows x 31 columns]

# %%
lstm_path='./clean_data/lstm_predictions.csv'
lstm_df=pd.read_csv(lstm_path)
lstm_df
# Out:
#    Adansi North  Adansi South  Afigya Sekyere  Ahafo Ano North  \
# 0     17.739334     33.427525       -2.477716        -0.952109
# 1     17.915129     32.935196       -2.527560        -0.988093
# 2     17.583298     32.733727       -2.561215        -1.013218
# 3     17.779516     32.713577       -2.588688        -1.034337
# 4     17.822178     32.761680       -2.611337        -1.051687
#
#    Ahafo Ano South  Amansie Central  Amansie East  Amansie West  \
# 0        77.766320        18.046864     80.757675     73.495840
# 1        78.112840        17.107876     83.035850     75.753136
# 2        78.380806        16.407766     85.247960     76.107730
# 3        79.101610        15.909557     87.311740     76.720780
# 4        75.948250        15.509886     85.527410     74.807930
#
#    Asante Akim North  Asante Akim South  ...  Bibiani Anhwiaso Bekwai  \
# 0          15.377402          43.190870  ...                62.244347
# 1          15.343848          42.942913  ...                62.629246
# 2          15.319236          42.969704  ...                59.453674
# 3          15.331389          43.029156  ...                61.631320
# 4          15.034784          42.036720  ...                58.771034
#
#       Jomoro    Juabeso  Mpohor Wassa East  Nzema East  Sefwi Wiawso  \
# 0  10.672544  114.73856          58.908905   62.142680     58.109130
# 1  10.812530  117.36608          59.783646   62.908226     52.579950
# 2  10.875702  117.65493          59.754900   63.439697     49.854015
# 3  10.905189  118.69243          55.548250   64.463150     48.439420
# 4  10.928468  116.35807          56.738388   64.794430     47.895798
#
#    Shama Ahanta East  Wasa Amenfi East  Wasa Amenfi West  Wassa West
# 0          -1.881749          4.752080         -2.838346   13.061643
# 1          -1.925724          4.513899         -3.629869   12.781920
# 2          -1.957332          4.324954         -4.221790   12.631821
# 3          -1.982034          4.160496         -4.681381   12.527624
# 4          -2.001275          4.001905         -5.057912   12.474207
#
# [5 rows x 137 columns]

# %%
print("DataFrame shape:", lstm_df.shape)
print("Columns:", lstm_df.columns)
# Out:
# DataFrame shape: (5, 137)
# Columns: Index(['Adansi North', 'Adansi South', 'Afigya Sekyere', 'Ahafo Ano North',
#        'Ahafo Ano South', 'Amansie Central', 'Amansie East', 'Amansie West',
#        'Asante Akim North', 'Asante Akim South',
#        ...
#        'Bibiani Anhwiaso Bekwai', 'Jomoro', 'Juabeso', 'Mpohor Wassa East',
#        'Nzema East', 'Sefwi Wiawso', 'Shama Ahanta East', 'Wasa Amenfi East',
#        'Wasa Amenfi West', 'Wassa West'],
#       dtype='object', length=137)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras import Input

def load_data(file_path):
    try:
        data = pd.read_csv(file_path)
        return data
    except Exception as e:
        print(f"Error loading data from {file_path}: {e}")
        return None

def prepare_train_test_data(district_data, sequence_length=10):
    try:
        losses = district_data.loc[:, 'tc_loss_ha_2001':'tc_loss_ha_2023'].values.flatten()
        if len(losses) <= sequence_length:
            print(f"Not enough data for sequence preparation in district: {district_data['subnational2'].iloc[0]}")
            return None, None, None, None
        
        scaler = MinMaxScaler()
        losses_scaled = scaler.fit_transform(losses.reshape(-1, 1)).flatten()
        
        X, y = [], []
        for i in range(len(losses_scaled) - sequence_length):
            X.append(losses_scaled[i:i + sequence_length])
            y.append(losses_scaled[i + sequence_length])
        
        X, y = np.array(X).reshape((-1, sequence_length, 1)), np.array(y)
        
        # Split into train/test (2001-2018 for training, 2019-2023 for testing)
        train_size = 18  # 2001–2018
        X_train, y_train = X[:train_size], y[:train_size]
        test_scaled = losses_scaled[train_size:]
        
        return X_train, y_train, test_scaled, scaler
    except Exception as e:
        print(f"Error preparing data: {e}")
        return None, None, None, None

def build_lstm_model(input_shape):
    try:
        model = Sequential([
            Input(shape=input_shape),
            LSTM(50, activation='relu'),
            Dropout(0.2),
            Dense(1)
        ])
        model.compile(optimizer='adam', loss='mean_squared_error')
        return model
    except Exception as e:
        print(f"Error building LSTM model: {e}")
        return None

def evaluate_predictions(test_scaled, predictions, scaler):
    try:
        test_actual = scaler.inverse_transform(test_scaled.reshape(-1, 1)).flatten()
        test_predicted = scaler.inverse_transform(np.array(predictions).reshape(-1, 1)).flatten()
        mae = mean_absolute_error(test_actual, test_predicted)
        mse = mean_squared_error(test_actual, test_predicted)
        r2 = r2_score(test_actual, test_predicted)
        return mae, mse, r2, test_actual, test_predicted
    except Exception as e:
        print(f"Error evaluating predictions: {e}")
        return None, None, None, None, None

def plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, predictions):
    train_values = train_values[-len(train_years):]  # Align values to match years if necessary
    plt.figure(figsize=(12, 6))
    plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
    plt.plot(test_years, test_actual, label='Actual Data (2019-2023)', color='green', marker='o')
    plt.plot(pred_years, predictions, label='Predictions (2019-2023)', color='red', linestyle='dashed', marker='o')
    plt.title(f"Prediction Results for {district_name}")
    plt.xlabel("Year")
    plt.ylabel("Forest Loss")
    plt.legend()
    plt.grid()
    plt.savefig(f"./plots/all_years_{district_name}.png")

def process_district(district_data):
    try:
        if 'subnational2' not in district_data.columns or district_data.empty:
            raise ValueError("Invalid or empty district data")
        
        district_name = district_data['subnational2'].iloc[0]
        print(district_name)
        
        X_train, y_train, test_scaled, scaler = prepare_train_test_data(district_data)
        if X_train is None or y_train is None or len(X_train) == 0 or len(y_train) == 0:
            raise ValueError("Training data is missing or empty")
        
        if len(X_train.shape) != 3:
            raise ValueError("X_train should be a 3D array")
        
        model = build_lstm_model((X_train.shape[1], 1))
        
        try:
            model.fit(X_train, y_train, epochs=50, batch_size=16, verbose=0)
        except Exception as fit_error:
            raise ValueError(f"Error during model training: {fit_error}")
        
        if X_train.shape[0] == 0:
            raise ValueError("X_train is empty, cannot generate last sequence")
        
        last_sequence = X_train[-1].reshape(1, X_train.shape[1], 1)
        predictions = []
        for _ in range(len(test_scaled)):
            next_pred = model.predict(last_sequence, verbose=0)
            predictions.append(next_pred[0, 0])
            last_sequence = np.append(last_sequence[:, 1:, :], next_pred.reshape(1, 1, 1), axis=1)
        
        mae, mse, r2, test_actual, test_predicted = evaluate_predictions(test_scaled, predictions, scaler)
        print(f"District: {district_name} | MAE: {mae:.4f}, MSE: {mse:.4f}, R2: {r2:.4f}")
        
        train_years = list(range(2001, 2019))
        test_years = list(range(2019, 2024))
        pred_years = list(range(2019, 2024))
        train_values = scaler.inverse_transform(X_train[:, -1, 0].reshape(-1, 1)).flatten()
        print(f'train values are {len(train_values)}')
        
        try:
            plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
        except Exception as plot_error:
            raise ValueError(f"Error during plotting: {plot_error}")
        
        return test_predicted
    except Exception as e:
        import traceback
        print(f"Error processing district: {e}")
        print(traceback.format_exc())
        return None


def main():
    forest_path = './clean_data/forest.csv'
    forest_df = load_data(forest_path)
    if forest_df is None:
        return

    predictions_dict = {}
    districts = forest_df['subnational2'].unique()

    for district in districts:
        try:
            district_data = forest_df[forest_df['subnational2'] == district]
            #print(district_data)
            print('checking here')
            predictions = process_district(district_data)
            print('checking done')
            print(predictions)
            if predictions is not None:
                predictions_dict[district] = predictions
        except Exception as e:
            print(f"Error processing district {district}: {e}")
    
    predictions_df = pd.DataFrame(predictions_dict)
    predictions_df.to_csv('./clean_data/lstm_predictions.csv', index=False)
    print("Predictions saved successfully.")

if __name__ == "__main__":
    main()
# Out:
# checking here
# Adansi North
# District: Adansi North | MAE: 7.4440, MSE: 77.0682, R2: -0.2042
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Adansi South
# District: Adansi South | MAE: 34.8428, MSE: 1410.1015, R2: -1.7550
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Afigya Sekyere
# District: Afigya Sekyere | MAE: 2.8571, MSE: 8.1723, R2: 0.0000
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Ahafo Ano North
# District: Ahafo Ano North | MAE: 0.4307, MSE: 0.3104, R2: -0.2934
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Ahafo Ano South
# District: Ahafo Ano South | MAE: 46.5521, MSE: 2483.2350, R2: -0.1642
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Amansie Central
# District: Amansie Central | MAE: 42.9883, MSE: 4883.8674, R2: -0.1957
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Amansie East
# District: Amansie East | MAE: 51.2328, MSE: 4319.5629, R2: -0.0472
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Amansie West
# District: Amansie West | MAE: 60.5280, MSE: 4124.7821, R2: 0.0378
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Asante Akim North
# District: Asante Akim North | MAE: 6.6361, MSE: 58.8845, R2: -0.1035
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Asante Akim South
# District: Asante Akim South | MAE: 21.8028, MSE: 599.1042, R2: -0.0464
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Atwima
# District: Atwima | MAE: 1.1648, MSE: 1.5864, R2: -8.9153
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Atwima Mponua
# District: Atwima Mponua | MAE: 62.7074, MSE: 5594.3925, R2: 0.0953
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Bosomtwe-Kwanwoma
# District: Bosomtwe-Kwanwoma | MAE: 0.2886, MSE: 0.0833, R2: 0.0000
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Ejisu-Juabeng
# District: Ejisu-Juabeng | MAE: 1.4468, MSE: 2.1196, R2: 0.0000
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Ejura Sekyedumase
# District: Ejura Sekyedumase | MAE: 0.2939, MSE: 0.0869, R2: 0.0000
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Kumasi
# District: Kumasi | MAE: 0.0007, MSE: 0.0000, R2: 0.0000
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Kwabre
# District: Kwabre | MAE: 0.5698, MSE: 0.3268, R2: 0.0000
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Obuasi Municipal
# District: Obuasi Municipal | MAE: 8.2812, MSE: 101.4254, R2: -0.1994
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Offinso
# District: Offinso | MAE: 5.9805, MSE: 37.9613, R2: -0.0032
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Sekyere East
# District: Sekyere East | MAE: 0.9012, MSE: 0.8388, R2: 0.0000
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Sekyere West
# District: Sekyere West | MAE: 0.0729, MSE: 0.0054, R2: 0.0000
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Asunafo North
# /var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py:73: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(12, 6))
# District: Asunafo North | MAE: 87.5157, MSE: 9198.4011, R2: 0.0146
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Asunafo South
# District: Asunafo South | MAE: 34.4739, MSE: 1694.4249, R2: 0.0301
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Asutifi
# District: Asutifi | MAE: 7.4065, MSE: 82.5115, R2: -0.1814
# ...
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Hohoe
# District: Hohoe | MAE: 0.0512, MSE: 0.0026, R2: 0.0000
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Jasikan
# District: Jasikan | MAE: 0.0921, MSE: 0.0085, R2: 0.0000
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Kadjebi
# District: Kadjebi | MAE: 0.0903, MSE: 0.0082, R2: 0.0000
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Keta
# District: Keta | MAE: 0.0006, MSE: 0.0000, R2: 0.0000
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Ketu
# District: Ketu | MAE: 0.0000, MSE: 0.0000, R2: 1.0000
# train values are 13
# Error processing district: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 126, in process_district
#     plot_all_years(district_name, train_years, train_values, test_years, test_actual, pred_years, test_predicted)
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 74, in plot_all_years
#     plt.plot(train_years, train_values, label='Training Data (2001-2018)', color='blue', marker='o')
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py", line 486, in _plot_args
#     raise ValueError(f"x and y must have same first dimension, but "
# ValueError: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/9l/7llcw8rd1jjgq13k9ckd1sf80000gr/T/ipykernel_53386/3872787720.py", line 128, in process_district
#     raise ValueError(f"Error during plotting: {plot_error}")
# ValueError: Error during plotting: x and y must have same first dimension, but have shapes (18,) and (13,)
#
# checking done
# None
# checking here
# Kpandu
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 165
#     162     print("Predictions saved successfully.")
#     164 if __name__ == "__main__":
# --> 165     main()
#
# Cell In[4], line 152, in main()
#     150 #print(district_data)
#     151 print('checking here')
# --> 152 predictions = process_district(district_data)
#     153 print('checking done')
#     154 print(predictions)
#
# Cell In[4], line 102, in process_district(district_data)
#      99 model = build_lstm_model((X_train.shape[1], 1))
#     101 try:
# --> 102     model.fit(X_train, y_train, epochs=50, batch_size=16, verbose=0)
#     103 except Exception as fit_error:
#     104     raise ValueError(f"Error during model training: {fit_error}")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:318, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     316 callbacks.on_epoch_begin(epoch)
#     317 with epoch_iterator.catch_stop_iteration():
# --> 318     for step, iterator in epoch_iterator.enumerate_epoch():
#     319         callbacks.on_train_batch_begin(step)
#     320         logs = self.train_function(iterator)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:689, in TFEpochIterator.enumerate_epoch(self)
#     687         yield step, self._current_iterator
#     688 else:
# --> 689     iterator = iter(self._distributed_dataset)
#     690     if self.num_batches:
#     691         for step in range(
#     692             0, self.num_batches, self.steps_per_execution
#     693         ):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/data/ops/dataset_ops.py:501, in DatasetV2.__iter__(self)
#     499 if context.executing_eagerly() or ops.inside_function():
#     500   with ops.colocate_with(self._variant_tensor):
# --> 501     return iterator_ops.OwnedIterator(self)
#     502 else:
#     503   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     504                      "iteration in eager mode or within tf.function.")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/data/ops/iterator_ops.py:705, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     701   if (components is not None or element_spec is not None):
#     702     raise ValueError(
#     703         "When `dataset` is provided, `element_spec` and `components` must "
#     704         "not be specified.")
# --> 705   self._create_iterator(dataset)
#     707 self._get_next_call_count = 0
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/data/ops/iterator_ops.py:744, in OwnedIterator._create_iterator(self, dataset)
#     741   assert len(fulltype.args[0].args[0].args) == len(
#     742       self._flat_output_types)
#     743   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 744 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/ops/gen_dataset_ops.py:3478, in make_iterator(dataset, iterator, name)
#    3476 if tld.is_eager:
#    3477   try:
# -> 3478     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3479       _ctx, "MakeIterator", name, dataset, iterator)
#    3480     return _result
#    3481   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
import os
forest_path='./clean_data/forest.csv'
forest_df=pd.read_csv(forest_path)
# adansi_df=forest_df[forest_df['subnational2']=='Adansi North']
# adansi_df
forest_df.head()
# Out:
#   country subnational1     subnational2  threshold  area_ha  extent_2000_ha  \
# 0   Ghana      Ashanti     Adansi North         75    61269            4520
# 1   Ghana      Ashanti     Adansi South         75   140792            8051
# 2   Ghana      Ashanti   Afigya Sekyere         75    66797             454
# 3   Ghana      Ashanti  Ahafo Ano North         75    72965             141
# 4   Ghana      Ashanti  Ahafo Ano South         75   120724            3548
#
#    extent_2010_ha  gain_2000-2020_ha  tc_loss_ha_2001  tc_loss_ha_2002  ...  \
# 0            2921               2041               23               80  ...
# 1            8276               3296              122              129  ...
# 2             193               1516              100              122  ...
# 3              59               1538               39                8  ...
# 4            5870               3563              148              313  ...
#
#    tc_loss_ha_2014  tc_loss_ha_2015  tc_loss_ha_2016  tc_loss_ha_2017  \
# 0               40                5               17                6
# 1               12                1               24                6
# 2                0                0                0                0
# 3                0                0                0                0
# 4               44               10              197               96
#
#    tc_loss_ha_2018  tc_loss_ha_2019  tc_loss_ha_2020  tc_loss_ha_2021  \
# 0                8               11               31               16
# 1               54               34               94               69
# 2                0                0                0                0
# 3                0                0                0                1
# 4               91                7              139               35
#
#    tc_loss_ha_2022  tc_loss_ha_2023
# 0               21               31
# 1               94               86
# 2                0                0
# 3                0                1
# 4               52               24
#
# [5 rows x 31 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
X = forest_df[[f"tc_loss_ha_{year}" for year in range(2001, 2019)]]
y = forest_df[[f"tc_loss_ha_{year}" for year in range(2019, 2024)]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train,y_train )
y_pred_multi = rf_model.predict(X_test)
mae_multi = mean_absolute_error(y_test, y_pred_multi)
mse_multi = mean_squared_error(y_test, y_pred_multi)
r2_multi = r2_score(y_test, y_pred_multi)
print(f"Mean Absolute Error (MAE): {mae_multi:.2f}")
print(f"Mean Squared Error (MSE): {mse_multi:.2f}")
print(f"R² Score: {r2_multi:.2f}")
# Out:
# Mean Absolute Error (MAE): 6.62
# Mean Squared Error (MSE): 484.19
# R² Score: 0.58

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.multioutput import MultiOutputRegressor
X = forest_df[[f"tc_loss_ha_{year}" for year in range(2001, 2019)]]
y = forest_df[[f"tc_loss_ha_{year}" for year in range(2019, 2024)]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)
# Use MultiOutputRegressor to handle multiple outputs (for each year)
gb_model = GradientBoostingRegressor(n_estimators=100, random_state=42)
multi_target_model = MultiOutputRegressor(gb_model)
multi_target_model.fit(X_train, y_train)
y_pred_multi = multi_target_model.predict(X_test)
mae_multi = mean_absolute_error(y_test, y_pred_multi)
mse_multi = mean_squared_error(y_test, y_pred_multi)
r2_multi = r2_score(y_test, y_pred_multi)
print(f"Mean Absolute Error (MAE): {mae_multi:.2f}")
print(f"Mean Squared Error (MSE): {mse_multi:.2f}")
print(f"R² Score: {r2_multi:.2f}")
# Out:
# Mean Absolute Error (MAE): 6.97
# Mean Squared Error (MSE): 583.23
# R² Score: 0.54

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import StandardScaler
X = forest_df[[f"tc_loss_ha_{year}" for year in range(2001, 2019)]].values
y = forest_df[[f"tc_loss_ha_{year}" for year in range(2019, 2024)]].values
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
y_scaled = scaler.fit_transform(y)
X_scaled = X_scaled.reshape(X_scaled.shape[0], X_scaled.shape[1], 1)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.4, random_state=42)
model = Sequential()
model.add(LSTM(units=128, return_sequences=False, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(Dense(units=64))
model.add(Dropout(0.25))
model.add(Dense(units=5))
model.compile(optimizer='adam', loss='mean_squared_error')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1)
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), 
          callbacks=[early_stopping, reduce_lr])
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R² Score: {r2:.2f}")
# Out:
# Epoch 1/100
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step - loss: 1.0517 - val_loss: 0.8172 - learning_rate: 0.0010
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.8667 - val_loss: 0.6645 - learning_rate: 0.0010
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.7374 - val_loss: 0.5293 - learning_rate: 0.0010
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.6235 - val_loss: 0.4481 - learning_rate: 0.0010
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.4866 - val_loss: 0.4154 - learning_rate: 0.0010
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.5928 - val_loss: 0.3941 - learning_rate: 0.0010
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.4321 - val_loss: 0.3871 - learning_rate: 0.0010
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.4388 - val_loss: 0.3862 - learning_rate: 0.0010
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.5467 - val_loss: 0.3724 - learning_rate: 0.0010
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3311 - val_loss: 0.3600 - learning_rate: 0.0010
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.3389 - val_loss: 0.3545 - learning_rate: 0.0010
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.3470 - val_loss: 0.3668 - learning_rate: 0.0010
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3348 - val_loss: 0.3980 - learning_rate: 0.0010
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.3356 - val_loss: 0.4181 - learning_rate: 0.0010
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2913 - val_loss: 0.4027 - learning_rate: 0.0010
# Epoch 16/100
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.4033
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.3760 - val_loss: 0.3957 - learning_rate: 0.0010
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.3370 - val_loss: 0.4006 - learning_rate: 5.0000e-04
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.3998 - val_loss: 0.4075 - learning_rate: 5.0000e-04
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2828 - val_loss: 0.4085 - learning_rate: 5.0000e-04
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2361 - val_loss: 0.4119 - learning_rate: 5.0000e-04
# Epoch 21/100
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2619
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2930 - val_loss: 0.3966 - learning_rate: 5.0000e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# Mean Absolute Error (MAE): 0.23
# Mean Squared Error (MSE): 0.35
# R² Score: 0.62

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.multioutput import MultiOutputRegressor
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import StandardScaler

X = forest_df[[f"tc_loss_ha_{year}" for year in range(2001, 2019)]]
y = forest_df[[f"tc_loss_ha_{year}" for year in range(2019, 2024)]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)
r2_rf = r2_score(y_test, y_pred_rf)

gb_model = GradientBoostingRegressor(n_estimators=100, random_state=42)
multi_target_model = MultiOutputRegressor(gb_model)
multi_target_model.fit(X_train, y_train)
y_pred_multi = multi_target_model.predict(X_test)
r2_multi = r2_score(y_test, y_pred_multi)

X_scaled = StandardScaler().fit_transform(X)
y_scaled = StandardScaler().fit_transform(y)
X_scaled = X_scaled.reshape(X_scaled.shape[0], X_scaled.shape[1], 1)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.4, random_state=42)

model = Sequential()
model.add(LSTM(units=128, return_sequences=False, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(Dense(units=64))
model.add(Dropout(0.25))
model.add(Dense(units=5))
model.compile(optimizer='adam', loss='mean_squared_error')

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1)

model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), 
          callbacks=[early_stopping, reduce_lr])

y_pred_lstm = model.predict(X_test)
r2_lstm = r2_score(y_test, y_pred_lstm)

r2_scores = {'Random Forest': r2_rf, 'Gradient Boosting': r2_multi, 'LSTM': r2_lstm}

output_dir = 'lstm_evaluation'
os.makedirs(output_dir, exist_ok=True)

plt.figure(figsize=(8, 6))
plt.bar(r2_scores.keys(), r2_scores.values(), color=['blue', 'green', 'red'])
plt.xlabel('Model')
plt.ylabel('R² Score')
plt.title('R² Score for Different Models')
plt.ylim([0, 1])

plt.savefig(os.path.join(output_dir, 'r2_score.png'))
plt.show()

print(f"R² Score for Random Forest: {r2_rf:.2f}")
print(f"R² Score for Gradient Boosting: {r2_multi:.2f}")
print(f"R² Score for LSTM: {r2_lstm:.2f}")
# Out:
# Epoch 1/100
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 266ms/step - loss: 0.7856 - val_loss: 0.7076 - learning_rate: 0.0010
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.7795 - val_loss: 0.5585 - learning_rate: 0.0010
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.6348 - val_loss: 0.4520 - learning_rate: 0.0010
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.5757 - val_loss: 0.4118 - learning_rate: 0.0010
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.5602 - val_loss: 0.3935 - learning_rate: 0.0010
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.4503 - val_loss: 0.3895 - learning_rate: 0.0010
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.5035 - val_loss: 0.3921 - learning_rate: 0.0010
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.4411 - val_loss: 0.3828 - learning_rate: 0.0010
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.4287 - val_loss: 0.3586 - learning_rate: 0.0010
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.4001 - val_loss: 0.3462 - learning_rate: 0.0010
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2807 - val_loss: 0.3524 - learning_rate: 0.0010
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.3484 - val_loss: 0.3776 - learning_rate: 0.0010
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.3408 - val_loss: 0.4016 - learning_rate: 0.0010
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.3251 - val_loss: 0.4139 - learning_rate: 0.0010
# Epoch 15/100
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.3711
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.3501 - val_loss: 0.4244 - learning_rate: 0.0010
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.3508 - val_loss: 0.4188 - learning_rate: 5.0000e-04
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2617 - val_loss: 0.4136 - learning_rate: 5.0000e-04
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.3267 - val_loss: 0.4073 - learning_rate: 5.0000e-04
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2645 - val_loss: 0.4018 - learning_rate: 5.0000e-04
# Epoch 20/100
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.3836
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.3111 - val_loss: 0.3953 - learning_rate: 5.0000e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# R² Score for Random Forest: 0.58
# R² Score for Gradient Boosting: 0.54
# R² Score for LSTM: 0.63
